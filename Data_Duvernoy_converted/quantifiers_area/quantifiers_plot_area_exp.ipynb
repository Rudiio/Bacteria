# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Plotting the experimental quantifiers in function of the area
#
# The experimental quantifiers are plotted and compared to the simulations quantifiers.

# %%
## Simulations
# Simu 1 m7
ar1 = np.load("../../simulations/method7/quantifiers_area/aspect_ratio/simu1/simu1_aspect_ratio_mean7.npy")
d1 = np.load("../../simulations/method7/quantifiers_area/density/simu1/simu1_density_mean7.npy")
area1 = np.load("../../simulations/method7/quantifiers_area/area/simu1/simu1_area.npy")
N1 = np.load("../../simulations/method7/quantifiers_area/N/simu1/simu1_N_mean7.npy")

# # Simu 18 m7
# ar18 = np.load("../../simulations/method7/quantifiers/aspect_ratio_area/simu18/simu18_aspect_ratio_mean7.npy")
# d18 = np.load("../../simulations/method7/quantifiers/density_area/simu18/simu18_density_mean7.npy")
# area18= np.load("../../simulations/method7/quantifiers_area/area/simu1/simu1_area.npy")
# N18 = np.load("../../simulations/method7/quantifiers/N/simu18/simu18_N_mean7.npy")

# # Simu 19 m7
# ar19 = np.load("../../simulations/method7/quantifiers/aspect_ratio/simu22/simu22_aspect_ratio_mean7.npy")
# d19 = np.load("../../simulations/method7/quantifiers/density/simu22/simu22_density_mean7.npy")
# N19 = np.load("../../simulations/method7/quantifiers/N/simu22/simu22_N_mean7.npy")

# Simu 1m4
ar2 = np.load("../../simulations/quantifiers_data_area/aspect_ratio/simuc1/simuc1_aspect_ratio_mean4.npy")
d2 = np.load("../../simulations/quantifiers_data_area/density/simuc1/simuc1_density_mean4.npy")
area2 = np.load("../../simulations/quantifiers_data_area/area/simuc1/simuc1_area.npy")
N2 = np.load("../../simulations/quantifiers_data_area/N/simuc1/simuc1_N_mean4.npy")

## Experimental
#  Coli1
arc1 = np.load("./aspect_ratio/Coli1_aspect_ratio.npy")
dc1 = np.load("./density/Coli1_density.npy")
Nc1 = np.load("./N/Coli1_N.npy")
areac1 = np.load("./area/Coli1_area.npy")

#  Coli2
arc2 = np.load("./aspect_ratio/Coli2_aspect_ratio.npy")
dc2 = np.load("./density/Coli2_density.npy")
Nc2 = np.load("./N/Coli2_N.npy")
areac2 = np.load("./area/Coli2_area.npy")

#  Coli3
arc3 = np.load("./aspect_ratio/Coli3_aspect_ratio.npy")
dc3 = np.load("./density/Coli3_density.npy")
Nc3 = np.load("./N/Coli3_N.npy")
areac3 = np.load("./area/Coli3_area.npy")

#  Coli4
arc4 = np.load("./aspect_ratio/Coli4_aspect_ratio.npy")
dc4 = np.load("./density/Coli4_density.npy.")
Nc4 = np.load("./N/Coli4_N.npy")
areac4 = np.load("./area/Coli4_area.npy")

#  Coli5
arc5 = np.load("./aspect_ratio/Coli5_aspect_ratio.npy")
dc5 = np.load("./density/Coli5_density.npy")
Nc5 = np.load("./N/Coli5_N.npy")
areac5 = np.load("./area/Coli5_area.npy")

#  Coli6
arc6 = np.load("./aspect_ratio/Coli6_aspect_ratio.npy")
dc6 = np.load("./density/Coli6_density.npy")
Nc6 = np.load("./N/Coli6_N.npy")
areac6 = np.load("./area/Coli6_area.npy")

#  Coli7
arc7 = np.load("./aspect_ratio/Coli7_aspect_ratio.npy")
dc7 = np.load("./density/Coli7_density.npy")
Nc7 = np.load("./N/Coli7_N.npy")
areac7 = np.load("./area/Coli7_area.npy")

plt.figure(figsize=[10,8])
plt.plot(areac1,arc1,"--",label="Coli1")
plt.plot(areac2,arc2,"--",label="Coli2")
plt.plot(areac3,arc3,"--",label="Coli3")
plt.plot(areac4,arc4,"--",label="Coli4")
plt.plot(areac5,arc5,"--",label="Coli5")
plt.plot(areac6,arc6,"--",label="Coli6")
plt.plot(areac7,arc7,"--",label="Coli7")
plt.plot(area1,ar1,label = "simu1 m7")
plt.plot(area2,ar2,label = "simu1 m4")
# plt.plot(L2,ar18[:-1],label = "simu18 m7")
# plt.plot(LL,ar19,label = "simu1 gk")
plt.title("Aspect ratio as a function of the area")
plt.xlabel("area in $\mu m^2$")
plt.ylabel(r"$\alpha_r$")
plt.legend()
plt.show()

plt.figure(figsize=[10,8])
plt.plot(areac1,dc1,"--",label="Coli1")
plt.plot(areac2,dc2,"--",label="Coli2")
plt.plot(areac3,dc3,"--",label="Coli3")
plt.plot(areac4,dc4,"--",label="Coli4")
plt.plot(areac5,dc5,"--",label="Coli5")
plt.plot(areac6,dc6,"--",label="Coli6")
plt.plot(areac7,dc7,"--",label="Coli7")
plt.plot(area1,d1,label = "simu1 m7")
plt.plot(area2,d2,label = "simu1 m4")
# plt.plot(L2,d18[:-1],label = "simu18 m7")
# plt.plot(LL,d19,label = "simu1 gk")
plt.title("density as a function of the area")
plt.xlabel("area in $\mu m^2$")
plt.ylabel(r"$\delta$")
plt.legend()
plt.show()

plt.figure(figsize=[10,8])
plt.plot(areac1,Nc1,"--",label="Coli1")
plt.plot(areac2,Nc2,"--",label="Coli2")
plt.plot(areac3,Nc3,"--",label="Coli3")
plt.plot(areac4,Nc4,"--",label="Coli4")
plt.plot(areac5,Nc5,"--",label="Coli5")
plt.plot(areac6,Nc6,"--",label="Coli6")
plt.plot(areac7,Nc7,"--",label="Coli7")
plt.plot(area1,N1,label = "simu1 m7")
plt.plot(area2,N2,label = "simu1 m4")
# plt.plot(L2,N18[:-1],label = "simu18 m7")
# plt.plot(LL,N19,label = "simu1 gk")
# plt.plot(tc6,np.exp(0.04*tc6))
plt.title("Number of bacteria as a function of the area")
plt.xlabel("area in $\mu m^2$")
plt.ylabel(r"$N$")
plt.legend()
plt.show()
