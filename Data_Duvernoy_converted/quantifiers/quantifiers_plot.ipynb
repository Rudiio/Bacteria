# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

# %% [markdown]
# # Plotting the experimental quantifiers in function of time
#
# The experimental quantifiers are plotted and compared to the simulations quantifiers.

# %%
# Time arrays
L = [i for i in range(3,200,3)]
L.append(200)
L = np.array(L)

LL = [i for i in range(3,150,3)]
LL.append(150)

L2 = [i for i in range(3,250,3)]

## Simulations
# Simu 1 m7
ar1 = np.load("../../simulations/method7/quantifiers/aspect_ratio/simu1/simu1_aspect_ratio_mean7.npy")
d1 = np.load("../../simulations/method7/quantifiers/density/simu1/simu1_density_mean7.npy")
N1 = np.load("../../simulations/method7/quantifiers/N/simu1/simu1_N_mean7.npy")

# Simu 18 m7
ar18 = np.load("../../simulations/method7/quantifiers/aspect_ratio/simu18/simu18_aspect_ratio_mean7.npy")
d18 = np.load("../../simulations/method7/quantifiers/density/simu18/simu18_density_mean7.npy")
N18 = np.load("../../simulations/method7/quantifiers/N/simu18/simu18_N_mean7.npy")

# Simu 19 m7 avec gk différent
ar19 = np.load("../../simulations/method7/quantifiers/aspect_ratio/simu22/simu22_aspect_ratio_mean7.npy")
d19 = np.load("../../simulations/method7/quantifiers/density/simu22/simu22_density_mean7.npy")
N19 = np.load("../../simulations/method7/quantifiers/N/simu22/simu22_N_mean7.npy")

# Simu 1m4
ar2 = np.load("../../simulations/quantifiers_data/aspect_ratio/simuc1/simuc1_aspect_ratio_mean.npy")
d2 = np.load("../../simulations/quantifiers_data/density/simuc1/simuc1_density_mean.npy")
N2 = np.load("../../simulations/quantifiers_data/N/simuc1/simuc1_N_mean.npy")

## Experimental
#  Coli1
arc1 = np.load("./aspect_ratio/Coli1_aspect_ratio.npy")
dc1 = np.load("./density/Coli1_density.npy")
tc1 = np.load("./time/Coli1_time.npy")
Nc1 = np.load("./N/Coli1_N.npy")

#  Coli2
arc2 = np.load("./aspect_ratio/Coli2_aspect_ratio.npy")
dc2 = np.load("./density/Coli2_density.npy")
tc2 = np.load("./time/Coli2_time.npy")
Nc2 = np.load("./N/Coli2_N.npy")

#  Coli3
arc3 = np.load("./aspect_ratio/Coli3_aspect_ratio.npy")
dc3 = np.load("./density/Coli3_density.npy")
tc3 = np.load("./time/Coli3_time.npy")
Nc3 = np.load("./N/Coli3_N.npy")

#  Coli4
arc4 = np.load("./aspect_ratio/Coli4_aspect_ratio.npy")
dc4 = np.load("./density/Coli4_density.npy.")
tc4 = np.load("./time/Coli4_time.npy")
Nc4 = np.load("./N/Coli4_N.npy")

#  Coli5
arc5 = np.load("./aspect_ratio/Coli5_aspect_ratio.npy")
dc5 = np.load("./density/Coli5_density.npy")
tc5 = np.load("./time/Coli5_time.npy")
Nc5 = np.load("./N/Coli5_N.npy")

#  Coli3
arc6 = np.load("./aspect_ratio/Coli6_aspect_ratio.npy")
dc6 = np.load("./density/Coli6_density.npy")
tc6 = np.load("./time/Coli6_time.npy")
Nc6 = np.load("./N/Coli6_N.npy")

plt.figure(figsize=[10,8])
plt.plot(tc1,arc1,"--",label="Coli1")
plt.plot(tc2,arc2,"--",label="Coli2")
plt.plot(tc3,arc3,"--",label="Coli3")
# plt.plot(t4,ar4,label="Coli4")
# plt.plot(t5,ar5,label="Coli5")
plt.plot(tc6,arc6,"--",label="Coli6")
# plt.plot(L,ar1,label = "simu1 m7")
# plt.plot(L,ar2,label = "simu1 m4")
# plt.plot(L2,ar18[:-1],label = "simu18 m7")
plt.plot(LL,ar19,label = "simu1 gk")
plt.title("Aspect ratio as a function of time")
plt.xlabel("time (in min)")
plt.ylabel(r"$\alpha_r$")
plt.legend()
plt.show()

plt.figure(figsize=[10,8])
plt.plot(tc1,dc1,"--",label="Coli1")
plt.plot(tc2,dc2,"--",label="Coli2")
plt.plot(tc3,dc3,"--",label="Coli3")
# plt.plot(t4,d4,label="Coli4")
# plt.plot(t5,d5,label="Coli5")
plt.plot(tc6,dc6,"--",label="Coli6")
# plt.plot(L,d1,label = "simu1 m7")
# plt.plot(L,d2,label = "simu1 m4")
# plt.plot(L2,d18[:-1],label = "simu18 m7")
plt.plot(LL,d19,label = "simu1 gk")
plt.title("density as a function of time")
plt.xlabel("time (in min)")
plt.ylabel(r"$\delta$")
plt.legend()
plt.show()

plt.figure(figsize=[10,8])
plt.plot(tc1,Nc1,"--",label="Coli1")
# plt.plot(tc2,Nc2,"--",label="Coli2")
plt.plot(tc3,Nc3,"--",label="Coli3")
# plt.plot(t4,d4,label="Coli4")
# plt.plot(t5,d5,label="Coli5")
plt.plot(tc6,Nc6,"--",label="Coli6")
# plt.plot(L,N1,label = "simu1 m7")
# plt.plot(L,N2,label = "simu1 m4")
# plt.plot(L2,N18[:-1],label = "simu18 m7")
plt.plot(LL,N19,label = "simu1 gk")
# plt.plot(tc6,np.exp(0.04*tc6))
plt.title("Number of bacteria as a function of time")
plt.xlabel("time (in min)")
plt.ylabel(r"$N$")
plt.legend()
plt.show()
