# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import os

# %% [markdown]
# # Plottig the area in function of the area for method 7

# %% [markdown]
# # Means calculations
#
# After calculating the quantifiers with the corresponding jupyter notebook, the first step is to calculate the means for the serie of simulation.
#
# The following code calculate the means for a certain serie.

# %%
file = "simu16"

#aspect ratio
all_files = glob.glob("./aspect_ratio/"+ file +"/*.npy")
arrays = [np.load(all_files[i]) for i in range(len(all_files))]
S = arrays[0]
for i in range(1,len(arrays)):
    S += arrays[i]
S/=len(arrays)

if "./aspect_ratio/"+ file +"/"+ file + "_aspect_ratio_mean7.npy" in all_files:
    os.remove("./aspect_ratio/"+ file +"/"+ file + "_aspect_ratio_mean7.npy")

np.save("./aspect_ratio/"+ file +"/"+ file + "_aspect_ratio_mean7.npy",S)

#density
all_files = glob.glob("./density/"+ file +"/*.npy")
arrays = [np.load(all_files[i]) for i in range(len(all_files))]
S = arrays[0]
for i in range(1,len(arrays)):
    S += arrays[i]
S/=len(arrays)

if "./density/"+ file +"/"+ file + "_density_mean7.npy" in all_files:
    os.remove("./density/"+ file +"/"+ file + "_density_mean7.npy")
np.save("./density/"+ file +"/"+ file + "_density_mean7.npy",S)

#length
all_files = glob.glob("./length/"+ file +"/*.npy")
arrays = [np.load(all_files[i]) for i in range(len(all_files))]
S = arrays[0]
for i in range(1,len(arrays)):
    S += arrays[i]
S/=len(arrays)

if "./length/"+ file +"/"+ file + "_length_mean7.npy" in all_files: 
    os.remove("./length/"+ file +"/"+ file + "_length_mean7.npy")
np.save("./length/"+ file +"/"+ file + "_length_mean7.npy",S)

#Number
all_files = glob.glob("./N/"+ file +"/*.npy")
arrays = [np.load(all_files[i]) for i in range(len(all_files))]
S = np.zeros(arrays[0].shape[0])
for i in range(0,len(arrays)):
    S += arrays[i]
avg = []
for i in range(S.shape[0]):
    avg.append(S[i]/len(arrays))

if "./N/"+ file +"/"+ file + "_N_mean7.npy" in all_files:
    os.remove("./N/"+ file +"/"+ file + "_N_mean7.npy")
np.save("./N/"+ file +"/"+ file + "_N_mean7.npy",np.array(avg))

#El
all_files = glob.glob("./energies/"+ file +"/El/*.npy")
arrays = [np.load(all_files[i]) for i in range(len(all_files))]
S = arrays[0]
for i in range(1,len(arrays)):
     S += arrays[i]
S/=len(arrays)

if "./energies/"+ file +"/"+ file +"_El_mean7" in all_files: 
    os.remove("./energies/"+ file +"/"+ file +"_El_mean7")
np.save("./energies/"+ file +"/"+ file +"_El_mean7",S)

#Et
all_files = glob.glob("./energies/"+ file +"/Et/*.npy")
arrays = [np.load(all_files[i]) for i in range(len(all_files))]
S = arrays[0]
for i in range(1,len(arrays)):
    S += arrays[i]
S/=len(arrays)

if "./energies/"+ file +"/"+ file +"_Et_mean7" in all_files:
    os.remove("./energies/"+ file +"/"+ file +"_Et_mean7")
np.save("./energies/"+ file +"/"+ file +"_Et_mean7",S)

# %% [markdown]
# # Plotting the quantifiers in function of the area
#
# The parameters for the simulation can be founf [here](https://docs.google.com/spreadsheets/d/1uAUMcMqwhV0PLzKSrlt9hVk2t99TNwWRTTTWq0dSBC0/edit#gid=559599640)

# %% [markdown]
# # Variating ks
#
# Here we load and plot all the simulations corresponding to variations of linear stiffness $k_s$

# %%
# Simu 14
ar14 = np.load("./aspect_ratio/simu14/simu14_aspect_ratio_mean7.npy")
d14 = np.load("./density/simu14/simu14_density_mean7.npy")
s14 = np.load("./length/simu14/simu14_length_mean7.npy")
Et14 = np.load("./energies/simu14/simu14_Et_mean7.npy")
El14 = np.load("./energies/simu14/simu14_El_mean7.npy")
area14  = np.load("./area/simu14/simu14_area.npy")

# Simu 1
ar1 = np.load("./aspect_ratio/simu1/simu1_aspect_ratio_mean7.npy")
d1 = np.load("./density/simu1/simu1_density_mean7.npy")
s1 = np.load("./length/simu1/simu1_length_mean7.npy")
Et1 = np.load("./energies/simu1/simu1_Et_mean7.npy")
El1 = np.load("./energies/simu1/simu1_El_mean7.npy")
area1  = np.load("./area/simu1/simu1_area.npy")

# Simu 2
ar2 = np.load("./aspect_ratio/simu2/simu2_aspect_ratio_mean7.npy")
d2 = np.load("./density/simu2/simu2_density_mean7.npy")
s2 = np.load("./length/simu2/simu2_length_mean7.npy")
Et2 = np.load("./energies/simu2/simu2_Et_mean7.npy")
El2 = np.load("./energies/simu2/simu2_El_mean7.npy")
area2  = np.load("./area/simu2/simu2_area.npy")

# Simu 3
ar3 = np.load("./aspect_ratio/simu3/simu3_aspect_ratio_mean7.npy")
d3 = np.load("./density/simu3/simu3_density_mean7.npy")
s3 = np.load("./length/simu3/simu3_length_mean7.npy")
Et3 = np.load("./energies/simu3/simu3_Et_mean7.npy")
El3 = np.load("./energies/simu3/simu3_El_mean7.npy")
area3  = np.load("./area/simu3/simu3_area.npy")

# Simu 5
ar4 = np.load("./aspect_ratio/simu4/simu4_aspect_ratio_mean7.npy")
d4 = np.load("./density/simu4/simu4_density_mean7.npy")
s4 = np.load("./length/simu4/simu4_length_mean7.npy")
Et4 = np.load("./energies/simu4/simu4_Et_mean7.npy")
El4 = np.load("./energies/simu4/simu4_El_mean7.npy")
area4  = np.load("./area/simu4/simu4_area.npy")

# Simu 5
ar5 = np.load("./aspect_ratio/simu5/simu5_aspect_ratio_mean7.npy")
d5 = np.load("./density/simu5/simu5_density_mean7.npy")
s5 = np.load("./length/simu5/simu5_length_mean7.npy")
Et5 = np.load("./energies/simu5/simu5_Et_mean7.npy")
El5 = np.load("./energies/simu5/simu5_El_mean7.npy")
area5  = np.load("./area/simu5/simu5_area.npy")

plt.figure(figsize=[10,8])
plt.plot(area14,ar14,"-",label="$m_7 k_s$ = 15")
plt.plot(area1,ar1,"-",label="$m_7 k_s$ = 10")
plt.plot(area2,ar2,"-",label="$m_7 k_s$ = 5")
plt.plot(area3,ar3,"-",label="$m_7 k_s$ = 1")
plt.plot(area4,ar4[:7],"-",label="$m_7 k_s$ = 0.5")
plt.plot(area5,ar5,"-",label="$m_7 k_s$ = 0.1")
plt.title("Aspect ratio as a function of the area")
plt.xlabel("area in $\mu m^2$")
plt.ylabel(r"$\alpha_r$")
plt.legend()
plt.show()

plt.figure(figsize=[10,8])
plt.plot(area14,d14,"-",label="$m_7 k_s$ = 15")
plt.plot(area1,d1,"-",label="$m_7 k_s$ = 10")
plt.plot(area2,d2,"-",label="$m_7 k_s$ = 5")
plt.plot(area3,d3,"-",label="$m_7 k_s$ = 1")
plt.plot(area4,d4[:7],"-",label="$m_7 k_s$ = 0.5")
plt.plot(area5,d5,"-",label="$m_7 k_s$ = 0.1")
plt.title("density as a function of the area")
plt.xlabel("area in $\mu m^2$")
plt.ylabel(r"$\delta$")
plt.legend()
plt.show()

plt.figure(figsize=[10,8])
plt.plot(area14,s14,"-",label="$m_7 k_s$ = 15")
plt.plot(area1,s1,"-",label="$m_7 k_s$ = 10")
plt.plot(area2,s2,"-",label="$m_7 k_s$ = 5")
plt.plot(area3,s3,"-",label="$m_7 k_s$ = 1")
plt.plot(area4,s4[:7],"-",label="$m_7 k_s$ = 0.5")
plt.plot(area5,s5,"-",label="$m_7 k_s$ = 0.1")
plt.title("length quantifier as a function of the  area")
plt.xlabel("area in $\mu m^2$")
plt.ylabel(r"$s$")
plt.legend()
plt.show()

plt.figure(figsize=[10,8])
plt.plot(area14,Et14,"-",label="$m_7 k_s$ = 15")
plt.plot(area1,Et1,label="$m_7$ $k_s=10$")
plt.plot(area2,Et2,label="$m_7$ $k_s=5$")
plt.plot(area3,Et3,label="$m_7$ $k_s=1$")
plt.plot(area4,Et4[:7],label="$m_7$  $k_s=0.5$")
plt.plot(area5,Et5,label="$m_7$ $k_s=0.1$")
plt.title("Bending energy in function of the area")
plt.xlabel("area in $\mu m^2$")
plt.ylabel(r"$s$")
plt.legend()
plt.show()

plt.figure(figsize=[10,8])
plt.plot(area14,El14,"-",label="$m_7 k_s$ = 15")
plt.plot(area1,El1,label="$m_7$ $k_s=10$")
plt.plot(area2,El2,label="$m_7$ $k_s=5$")
plt.plot(area3,El3,label="$m_7$ $k_s=1$")
plt.plot(area4,El4[:7],label="$m_7$ $k_s=0.5$")
plt.plot(area5,El5,label="$m_7$ $k_s=0.1$")
plt.title("Linear energy in function of the area")
plt.xlabel("area in $\mu m^2$")
plt.ylabel(r"$s$")
plt.legend()
plt.show()

# %% [markdown]
# # Variating kt
#
# Here we load and plot all the simulations corresponding to variations of torsion stiffness $k_t$

# %%
# Simu 15
ar15 = np.load("./aspect_ratio/simu15/simu15_aspect_ratio_mean7.npy")
d15 = np.load("./density/simu15/simu15_density_mean7.npy")
s15 = np.load("./length/simu15/simu15_length_mean7.npy")
Et15 = np.load("./energies/simu15/simu15_Et_mean7.npy")
El15 = np.load("./energies/simu15/simu15_El_mean7.npy")
area15  = np.load("./area/simu15/simu15_area.npy")

# Simu 6
ar6 = np.load("./aspect_ratio/simu6/simu6_aspect_ratio_mean7.npy")
d6 = np.load("./density/simu6/simu6_density_mean7.npy")
s6 = np.load("./length/simu6/simu6_length_mean7.npy")
Et6 = np.load("./energies/simu6/simu6_Et_mean7.npy")
El6 = np.load("./energies/simu6/simu6_El_mean7.npy")
area6  = np.load("./area/simu6/simu6_area.npy")

# Simu 7
ar7 = np.load("./aspect_ratio/simu7/simu7_aspect_ratio_mean7.npy")
d7 = np.load("./density/simu7/simu7_density_mean7.npy")
s7 = np.load("./length/simu7/simu7_length_mean7.npy")
Et7 = np.load("./energies/simu7/simu7_Et_mean7.npy")
El7 = np.load("./energies/simu7/simu7_El_mean7.npy")
area7 = np.load("./area/simu7/simu7_area.npy")

# Simu 8
ar8 = np.load("./aspect_ratio/simu8/simu8_aspect_ratio_mean7.npy")
d8 = np.load("./density/simu8/simu8_density_mean7.npy")
s8 = np.load("./length/simu8/simu8_length_mean7.npy")
Et8 = np.load("./energies/simu8/simu8_Et_mean7.npy")
El8 = np.load("./energies/simu8/simu8_El_mean7.npy")
area8  = np.load("./area/simu8/simu8_area.npy")

# Simu 9
ar9 = np.load("./aspect_ratio/simu9/simu9_aspect_ratio_mean7.npy")
d9 = np.load("./density/simu9/simu9_density_mean7.npy")
s9 = np.load("./length/simu9/simu9_length_mean7.npy")
Et9 = np.load("./energies/simu9/simu9_Et_mean7.npy")
El9 = np.load("./energies/simu9/simu9_El_mean7.npy")
area9  = np.load("./area/simu9/simu9_area.npy")


plt.figure(figsize=[10,8])
plt.plot(area15,ar15,"-",label="$m_7 k_t$ = 15")
plt.plot(area1,ar1,"-",label="$m_7 k_t$ = 10")
plt.plot(area6,ar6,"-",label="$m_7 k_t$ = 5")
plt.plot(area7,ar7,"-",label="$m_7 k_t$ = 1")
plt.plot(area8,ar8,"-",label="$m_7 k_t$ = 0.5")
plt.plot(area9,ar9,"-",label="$m_7 k_t$ = 0.1")
plt.title("Aspect ratio as a function of the area")
plt.xlabel("area in $\mu m^2$")
plt.ylabel(r"$\alpha_r$")
plt.legend()
plt.show()

plt.figure(figsize=[10,8])
plt.plot(area15,d15,"-",label="$m_7 k_s$ = 15")
plt.plot(area1,d1,"-",label="$m_7 k_t$ = 10")
plt.plot(area6,d6,"-",label="$m_7 k_t$ = 5")
plt.plot(area7,d7,"-",label="$m_7 k_t$ = 1")
plt.plot(area8,d8,"-",label="$m_7 k_t$ = 0.5")
plt.plot(area9,d9,"-",label="$m_7 k_t$ = 0.1")
plt.title("density as a function of the area")
plt.xlabel("area in $\mu m^2$")
plt.ylabel(r"$\delta$")
plt.legend()
plt.show()

plt.figure(figsize=[10,8])
plt.plot(area15,s15,"-",label="$m_7 k_t$ = 15")
plt.plot(area1,s1,"-",label="$m_7 k_t$ = 10")
plt.plot(area6,s6,"-",label="$m_7 k_t$ = 5")
plt.plot(area7,s7,"-",label="$m_7 k_t$ = 1")
plt.plot(area8,s8,"-",label="$m_7 k_t$ = 0.5")
plt.plot(area9,s9,"-",label="$m_7 k_t$ = 0.1")
plt.title("length quantifier as a function of the area")
plt.xlabel("area in $\mu m^2$")
plt.ylabel(r"$s$")
plt.legend()
plt.show()

plt.figure(figsize=[10,8])
plt.plot(area15,Et15,"-",label="$m_7 k_t$ = 15")
plt.plot(area1,Et1,label="$m_7$ $k_t=10$")
plt.plot(area6,Et6,label="$m_7$ $k_t=5$")
plt.plot(area7,Et7,label="$m_7$ $k_t=1$")
plt.plot(area8,Et8,label="$m_7$  $k_t=0.5$")
plt.plot(area9,Et9,label="$m_7$ $k_t=0.1$")
plt.title("Bending energy in function of the area")
plt.xlabel("area in $\mu m^2$")
plt.ylabel(r"$s$")
plt.legend()
plt.show()

plt.figure(figsize=[10,8])
plt.plot(area15,El15,"-",label="$m_7 k_t$ = 15")
plt.plot(area1,El1,label="$m_7$ $k_t=10$")
plt.plot(area6,El6,label="$m_7$ $k_t=5$")
plt.plot(area7,El7,label="$m_7$ $k_t=1$")
plt.plot(area8,El8,label="$m_7$ $k_t=0.5$")
plt.plot(area9,El9,label="$m_7$ $k_t=0.1$")
plt.title("Linear energy in function of the area")
plt.xlabel("area in $\mu m^2$")
plt.ylabel(r"$s$")
plt.legend()
plt.show()

# %% [markdown]
# # Variating kc
#
# Here we load and plot all the simulations corresponding to variations of collision stiffness $k_c$.

# %%
# Simu 16
ar16 = np.load("./aspect_ratio/simu16/simu16_aspect_ratio_mean7.npy")
d16 = np.load("./density/simu16/simu16_density_mean7.npy")
s16 = np.load("./length/simu16/simu16_length_mean7.npy")
Et16 = np.load("./energies/simu16/simu16_Et_mean7.npy")
El16 = np.load("./energies/simu16/simu16_El_mean7.npy")
area16  = np.load("./area/simu16/simu16_area.npy")

# Simu 10
ar10 = np.load("./aspect_ratio/simu10/simu10_aspect_ratio_mean7.npy")
d10 = np.load("./density/simu10/simu10_density_mean7.npy")
s10 = np.load("./length/simu10/simu10_length_mean7.npy")
Et10 = np.load("./energies/simu10/simu10_Et_mean7.npy")
El10 = np.load("./energies/simu10/simu10_El_mean7.npy")
area10  = np.load("./area/simu10/simu10_area.npy")

# Simu 11
ar11 = np.load("./aspect_ratio/simu11/simu11_aspect_ratio_mean7.npy")
d11 = np.load("./density/simu11/simu11_density_mean7.npy")
s11 = np.load("./length/simu11/simu11_length_mean7.npy")
Et11 = np.load("./energies/simu11/simu11_Et_mean7.npy")
El11 = np.load("./energies/simu11/simu11_El_mean7.npy")
area11 = np.load("./area/simu11/simu11_area.npy")

# Simu 12
ar12 = np.load("./aspect_ratio/simu12/simu12_aspect_ratio_mean7.npy")
d12 = np.load("./density/simu12/simu12_density_mean7.npy")
s12 = np.load("./length/simu12/simu12_length_mean7.npy")
Et12 = np.load("./energies/simu12/simu12_Et_mean7.npy")
El12 = np.load("./energies/simu12/simu12_El_mean7.npy")
area12  = np.load("./area/simu12/simu12_area.npy")

# Simu 9
ar13 = np.load("./aspect_ratio/simu13/simu13_aspect_ratio_mean7.npy")
d13 = np.load("./density/simu13/simu13_density_mean7.npy")
s13 = np.load("./length/simu13/simu13_length_mean7.npy")
Et13 = np.load("./energies/simu13/simu13_Et_mean7.npy")
El13 = np.load("./energies/simu13/simu13_El_mean7.npy")
area13  = np.load("./area/simu13/simu13_area.npy")


plt.figure(figsize=[10,8])
plt.plot(area16,ar16,"-",label="$m_7 k_c$ = 15")
plt.plot(area1,ar1,"-",label="$m_7 k_c$ = 10")
plt.plot(area10,ar10,"-",label="$m_7 k_c$ = 5")
plt.plot(area11,ar11,"-",label="$m_7 k_c$ = 1")
plt.plot(area12,ar12,"-",label="$m_7 k_c$ = 0.5")
plt.plot(area13,ar13,"-",label="$m_7 k_c$ = 0.1")
plt.title("Aspect ratio as a function of the area")
plt.xlabel("area in $\mu m^2$")
plt.ylabel(r"$\alpha_r$")
plt.legend()
plt.show()

plt.figure(figsize=[10,8])
plt.plot(area16,d16,"-",label="$m_7 k_c$ = 15")
plt.plot(area1,d1,"-",label="$m_7 k_c$ = 10")
plt.plot(area10,d10,"-",label="$m_7 k_c$ = 5")
plt.plot(area11,d11,"-",label="$m_7 k_c$ = 1")
plt.plot(area12,d12,"-",label="$m_7 k_c$ = 0.5")
plt.plot(area13,d13,"-",label="$m_7 k_c$ = 0.1")
plt.title("density as a function of the area")
plt.xlabel("area in $\mu m^2$")
plt.ylabel(r"$\delta$")
plt.legend()
plt.show()

plt.figure(figsize=[10,8])
plt.plot(area16,s16,"-",label="$m_7 k_c$ = 15")
plt.plot(area1,s1,"-",label="$m_7 k_c$ = 10")
plt.plot(area10,s10,"-",label="$m_7 k_c$ = 5")
plt.plot(area11,s11,"-",label="$m_7 k_c$ = 1")
plt.plot(area12,s12,"-",label="$m_7 k_c$ = 0.5")
plt.plot(area13,s13,"-",label="$m_7 k_c$ = 0.1")
plt.title("length quantifier as a function of the area")
plt.xlabel("area in $\mu m^2$")
plt.ylabel(r"$s$")
plt.legend()
plt.show()

plt.figure(figsize=[10,8])
plt.plot(area16,Et16,"-",label="$m_7 k_c$ = 15")
plt.plot(area1,Et1,label="$m_7$ $k_c=10$")
plt.plot(area10,Et10,label="$m_7$ $k_c=5$")
plt.plot(area11,Et11,label="$m_7$ $k_c=1$")
plt.plot(area12,Et12,label="$m_7$  $k_c=0.5$")
plt.plot(area13,Et13,label="$m_7$ $k_c=0.1$")
plt.title("Bending energy in function of the area")
plt.xlabel("area in $\mu m^2$")
plt.ylabel(r"$s$")
plt.legend()
plt.show()

plt.figure(figsize=[10,8])
plt.plot(area16,El16,"-",label="$m_7 k_c$ = 15")
plt.plot(area1,El1,label="$m_7$ $k_c=10$")
plt.plot(area10,El10,label="$m_7$ $k_c=5$")
plt.plot(area11,El11,label="$m_7$ $k_c=1$")
plt.plot(area12,El12,label="$m_7$ $k_c=0.5$")
plt.plot(area13,El13,label="$m_7$ $k_c=0.1$")
plt.title("Linear energy in function of the area")
plt.xlabel("area in $\mu m^2$")
plt.ylabel(r"$s$")
plt.legend()
plt.show()
