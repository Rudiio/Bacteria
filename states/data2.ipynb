# %%
import pandas as pd
import numpy as np

def convert(L):
    T = L.split(" ")
    T.pop()
    return np.array(T,dtype=float)

df = pd.read_csv("simu2.txt",sep="\t")

df["X"]=df["X"].apply(convert)
df
# Out:
#     N disks  Disks radius     time  Gen  ks  kt_bot  kt_par  kc  div_length  \
# 0         9           0.7  150.001    6  10      10      10  50    8.365568
# 1        10           0.7  150.001    6  10      10      10  50    7.681173
# 2        10           0.7  150.001    6  10      10      10  50    7.901262
# 3         9           0.7  150.001    6  10      10      10  50    7.365237
# 4         9           0.7  150.001    6  10      10      10  50    8.400060
# 5         9           0.7  150.001    6  10      10      10  50    7.630891
# 6        11           0.7  150.001    6  10      10      10  50    9.958338
# 7        11           0.7  150.001    6  10      10      10  50    8.513535
# 8         9           0.7  150.001    6  10      10      10  50    8.382018
# 9         9           0.7  150.001    6  10      10      10  50    9.402493
# 10        8           0.7  150.001    6  10      10      10  50    6.500059
# ...
